# %%
import pandas as pd
from pathlib import Path

# %%
crowd_df_path = Path(r"C:\Users\Maddy\Desktop\UNI\Homework\PROJECTS\P2\Starter_Files\Resources\crowdfunding.xlsx")
crowd_df = pd.read_excel(crowd_df_path)

# %%
crowd_df
# Out:
#      cf_id  contact_id                  company_name  \
# 0      147        4661    Baldwin, Riley and Jackson
# 1     1621        3765                      Odom Inc
# 2     1812        4187    Melton, Robinson and Fritz
# 3     2156        4941   Mcdonald, Gonzalez and Ross
# 4     1365        2199                 Larson-Little
# ..     ...         ...                           ...
# 995   2986        3684              Manning-Hamilton
# 996   2031        5784                    Butler LLC
# 997   1627        1498                      Ball LLC
# 998   2175        6073   Taylor, Santiago and Flores
# 999   1788        4939  Hernandez, Norton and Kelley
#
#                                              blurb    goal  pledged  \
# 0             Pre-emptive tertiary standardization     100        0
# 1                 Managed bottom-line architecture    1400    14560
# 2     Function-based leadingedge pricing structure  108400   142523
# ...

# %%
unique_values = crowd_df['category & sub-category'].str.split(expand=True).apply(lambda x: tuple(x.unique()), axis=0)
print(unique_values)
# Out:
# 0    (food/food, music/rock, technology/web, theate...
# 1         (trucks, None, &, music, rock, games, books)
# 2    (None, video/documentary, video/drama, video/a...
# 3                                      (None, fiction)
# dtype: object

# %%
#create a list for the column names 
proper_cols=list(crowd_df.columns)[14].split(',')
proper_cols
# Out:
# ['category & sub-category']

# %%
crowd_df[['category','subcategory']] = crowd_df ["category & sub-category"].str.split('/' , expand=True)
crowd_df.head()
# Out:
#    cf_id  contact_id                 company_name  \
# 0    147        4661   Baldwin, Riley and Jackson
# 1   1621        3765                     Odom Inc
# 2   1812        4187   Melton, Robinson and Fritz
# 3   2156        4941  Mcdonald, Gonzalez and Ross
# 4   1365        2199                Larson-Little
#
#                                            blurb    goal  pledged     outcome  \
# 0           Pre-emptive tertiary standardization     100        0      failed
# 1               Managed bottom-line architecture    1400    14560  successful
# 2   Function-based leadingedge pricing structure  108400   142523  successful
# 3  Vision-oriented fresh-thinking conglomeration    4200     2477      failed
# 4                      Proactive foreground core    7600     5265      failed
#
#    backers_count country currency  launched_at    deadline  staff_pick  \
# 0              0      CA      CAD   1581573600  1614578400       False
# ...

# %%
#create a dateframe that has Cat_ids with only Category titles 
categories = crowd_df['category'].unique()

# %%
# Create a DataFrame with category_id and category columns
category_df = pd.DataFrame({
    'category_id': [f'Cat{i+1}' for i in range(len(categories))],
    'category': categories
})

category_df
# Out:
#   category_id      category
# 0        Cat1          food
# 1        Cat2         music
# 2        Cat3    technology
# 3        Cat4       theater
# 4        Cat5  film & video
# 5        Cat6    publishing
# 6        Cat7         games
# 7        Cat8   photography
# 8        Cat9    journalism

# %%
#convert to csv - Crowdfunding - Cat 
category_df.to_csv('Starter_Files/Resources/Category.csv', index=False)

# %%
##SUB-CATEOGRY

# %%
#create a dateframe that has Cat_ids with only Category titles 
sub_categories=crowd_df['subcategory'].unique()

# %%
# Create a DataFrame with category_id and category columns
sub_categories_df = pd.DataFrame({
    'Sub-category_id': [f'Subcat{i+1}' for i in range(len(sub_categories))],
    'subcategory': sub_categories
})

sub_categories_df
# Out:
#    Sub-category_id        subcategory
# 0          Subcat1        food trucks
# 1          Subcat2               rock
# 2          Subcat3                web
# 3          Subcat4              plays
# 4          Subcat5        documentary
# 5          Subcat6     electric music
# 6          Subcat7              drama
# 7          Subcat8         indie rock
# 8          Subcat9          wearables
# 9         Subcat10         nonfiction
# 10        Subcat11          animation
# 11        Subcat12        video games
# 12        Subcat13             shorts
# 13        Subcat14            fiction
# 14        Subcat15  photography books
# 15        Subcat16   radio & podcasts
# 16        Subcat17              metal
# 17        Subcat18               jazz
# 18        Subcat19       translations
# 19        Subcat20         television
# 20        Subcat21       mobile games
# 21        Subcat22        world music
# 22        Subcat23    science fiction
# 23        Subcat24              audio

# %%
#convert to csv - Crowdfunding - SubCat
sub_categories_df.to_csv('Starter_Files/Resources/Sub Category.csv', index=False)

# %%
crowd_df.head()
# Out:
#    cf_id  contact_id                 company_name  \
# 0    147        4661   Baldwin, Riley and Jackson
# 1   1621        3765                     Odom Inc
# 2   1812        4187   Melton, Robinson and Fritz
# 3   2156        4941  Mcdonald, Gonzalez and Ross
# 4   1365        2199                Larson-Little
#
#                                            blurb    goal  pledged     outcome  \
# 0           Pre-emptive tertiary standardization     100        0      failed
# 1               Managed bottom-line architecture    1400    14560  successful
# 2   Function-based leadingedge pricing structure  108400   142523  successful
# 3  Vision-oriented fresh-thinking conglomeration    4200     2477      failed
# 4                      Proactive foreground core    7600     5265      failed
#
#    backers_count country currency  launched_at    deadline  staff_pick  \
# 0              0      CA      CAD   1581573600  1614578400       False
# ...

# %%
#creating the Dataframe with renmaning changes and datatype changes 


crowd_df.rename(columns={'blurb': 'Description'}, inplace=True)
crowd_df['goal'] = crowd_df['goal'].astype(float)
crowd_df['pledged'] = crowd_df['pledged'].astype(float)
crowd_df.rename(columns={'launched_at': 'launch_date'}, inplace=True)
crowd_df.rename(columns={'deadline': 'end_date'}, inplace=True)

# %%
crowd_df['launch_date'] = pd.to_datetime(crowd_df['launch_date'],dayfirst=True, yearfirst=True,format='mixed').dt.strftime('%d-%m-%y')
#crowd_df['end_date'] = pd.to_datetime(crowd_df['end_date'], format='%d-%m-%Y').dt.strftime('%d-%m-%y')

# %%
crowd_df
# Out:
#      cf_id  contact_id                  company_name  \
# 0      147        4661    Baldwin, Riley and Jackson
# 1     1621        3765                      Odom Inc
# 2     1812        4187    Melton, Robinson and Fritz
# 3     2156        4941   Mcdonald, Gonzalez and Ross
# 4     1365        2199                 Larson-Little
# ..     ...         ...                           ...
# 995   2986        3684              Manning-Hamilton
# 996   2031        5784                    Butler LLC
# 997   1627        1498                      Ball LLC
# 998   2175        6073   Taylor, Santiago and Flores
# 999   1788        4939  Hernandez, Norton and Kelley
#
#                                        Description      goal   pledged  \
# 0             Pre-emptive tertiary standardization     100.0       0.0
# 1                 Managed bottom-line architecture    1400.0   14560.0
# 2     Function-based leadingedge pricing structure  108400.0  142523.0
# ...
